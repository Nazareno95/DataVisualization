# %%
import pandas as pd

# %%
peliculas = pd.read_csv('C:\\Users\\Nazareno\\Desktop\\NAZARENO MEDRANO\\kunan-udemy\\desafio_baskball\\RatingsPeliculas.csv', sep=',',low_memory=False)

# %%
peliculas.head()
# Out:
#                 Pelicula    Genero  Ratings de Rotten Tomatoes %  \
# 0  (500) Days of Summer    Comedia                            87
# 1            10,000 B.C.  Aventura                             9
# 2             12 Rounds     Accion                            30
# 3              127 Hours  Aventura                            93
# 4              17 Again    Comedia                            55
#
#    Ratings de la Audience %  Presupuesto (millones USD)  Lanzamiento
# 0                        81                           8         2009
# 1                        44                         105         2008
# 2                        52                          20         2009
# 3                        84                          18         2010
# 4                        70                          20         2009

# %%
peliculas.columns
# Out:
# Index(['Pelicula', 'Genero', 'Ratings de Rotten Tomatoes %',
#        'Ratings de la Audience %', 'Presupuesto (millones USD)',
#        'Lanzamiento'],
#       dtype='object')

# %%
#normalizo nombres de las columnas
peliculas.columns = ['Peliculas','genero','RatingsCritico','RatingsAudiencia','PresupuestoMillonario','Año']

# %%
peliculas.columns
# Out:
# Index(['Peliculas', 'genero', 'RatingsCritico', 'RatingsAudiencia',
#        'PresupuestoMillonario', 'Año'],
#       dtype='object')

# %%
peliculas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Peliculas                559 non-null object
# genero                   559 non-null object
# RatingsCritico           559 non-null int64
# RatingsAudiencia         559 non-null int64
# PresupuestoMillonario    559 non-null int64
# Año                      559 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
peliculas.describe()
# Out:
#        RatingsCritico  RatingsAudiencia  PresupuestoMillonario          Año
# count      559.000000        559.000000             559.000000   559.000000
# mean        47.309481         58.744186              50.236136  2009.152057
# std         26.413091         16.826887              48.731817     1.362632
# min          0.000000          0.000000               0.000000  2007.000000
# 25%         25.000000         47.000000              20.000000  2008.000000
# 50%         46.000000         58.000000              35.000000  2009.000000
# 75%         70.000000         72.000000              65.000000  2010.000000
# max         97.000000         96.000000             300.000000  2011.000000

# %%
#convierto el tipo de dato de pelicuas a 'category'
peliculas.Peliculas = peliculas.Peliculas.astype('category')

# %%
peliculas.head()
# Out:
#                Peliculas    genero  RatingsCritico  RatingsAudiencia  \
# 0  (500) Days of Summer    Comedia              87                81
# 1            10,000 B.C.  Aventura               9                44
# 2             12 Rounds     Accion              30                52
# 3              127 Hours  Aventura              93                84
# 4              17 Again    Comedia              55                70
#
#    PresupuestoMillonario   Año
# 0                      8  2009
# 1                    105  2008
# 2                     20  2009
# 3                     18  2010
# 4                     20  2009

# %%
#aca se ve que peliculas se cambio a category 
peliculas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Peliculas                559 non-null category
# genero                   559 non-null object
# RatingsCritico           559 non-null int64
# RatingsAudiencia         559 non-null int64
# PresupuestoMillonario    559 non-null int64
# Año                      559 non-null int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 47.4+ KB

# %%
#hacer lo mismo pero para genero y año
peliculas.genero = peliculas.genero.astype('category')
peliculas.Año = peliculas.Año.astype('category')

# %%
peliculas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Peliculas                559 non-null category
# genero                   559 non-null category
# RatingsCritico           559 non-null int64
# RatingsAudiencia         559 non-null int64
# PresupuestoMillonario    559 non-null int64
# Año                      559 non-null category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
peliculas.genero.cat.categories
# Out:
# Index(['Accion', 'Aventura', 'Comedia', 'Drama', 'Romance', 'Suspenso',
#        'Terror'],
#       dtype='object')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#joinplots
j = sns.jointplot(data=peliculas, x ='RatingsCritico', y='RatingsAudiencia')

# %%
#graficos 1
j = sns.jointplot(data=peliculas, x ='RatingsCritico', y='RatingsAudiencia',kind='hex')

# %%
#histogramas
m1 = sns.distplot(peliculas.RatingsAudiencia)

# %%
m1 = sns.distplot(peliculas.RatingsAudiencia, bins=15)

# %%
m2 = sns.distplot(peliculas.RatingsCritico, bins=15)

# %%
#diagrama 2
n1 = plt.hist(peliculas.RatingsAudiencia, bins=15)

# %%
#diagrama 3
n2 = plt.hist(peliculas.RatingsCritico , bins=15)

# %%
#histogramas apiladas

peliculas[peliculas.genero == 'Drama']
#peliculas[peliculas.genero == 'Drama'].PresupuestoMillonario
# Out:
#                Peliculas genero  RatingsCritico  RatingsAudiencia  \
# 10            88 Minutes  Drama               5                51
# 11    A Dangerous Method  Drama              79                89
# 13        A Serious Man   Drama              89                64
# 18          Albert Nobbs  Drama              53                43
# 23       All Good Things  Drama              33                64
# ..                   ...    ...             ...               ...
# 529            War Horse  Drama              77                73
# 532  Water For Elephants  Drama              60                72
# 534     We Own the Night  Drama              55                63
# 541             Whip It   Drama              84                73
# 545        Winter's Bone  Drama              94                73
#
#      PresupuestoMillonario   Año
# 10                      30  2007
# 11                      20  2011
# 13                       7  2009
# 18                       8  2011
# ...

# %%
plt.hist(peliculas[peliculas.genero == 'Drama'].PresupuestoMillonario)
plt.show()

# %%
plt.hist(peliculas[peliculas.genero == 'Accion'].PresupuestoMillonario,bins=15)
plt.hist(peliculas[peliculas.genero == 'Drama'].PresupuestoMillonario,bins=15)
plt.hist(peliculas[peliculas.genero == 'Suspenso'].PresupuestoMillonario,bins=15)
plt.show()

# %%
plt.hist([peliculas[peliculas.genero == 'Drama'].PresupuestoMillonario, \
        peliculas[peliculas.genero == 'Suspenso'].PresupuestoMillonario],\
        bins=15, stacked=True)
plt.show()

# %%
peliculas.genero.cat.categories
# Out:
# Index(['Accion', 'Aventura', 'Comedia', 'Drama', 'Romance', 'Suspenso',
#        'Terror'],
#       dtype='object')

# %%
for gen in peliculas.genero.cat.categories:
    print(gen)
# Out:
# Accion
# Aventura
# Comedia
# Drama
# Romance
# Suspenso
# Terror

# %%
lista1 = list()
mis_etiquetas = list()
for gen in peliculas.genero.cat.categories:
    lista1.append(peliculas[peliculas.genero == gen].PresupuestoMillonario)
    mis_etiquetas.append(gen)
h = plt.hist(lista1,bins=30,stacked=True,rwidth=1, label=mis_etiquetas)
plt.legend()
plt.show()

# %%
#Graficos KDE
#diagrama de dispercion

# %%
vis1 = sns.lmplot(data=peliculas,x='RatingsCritico',y='RatingsAudiencia', fit_reg=False, hue='genero',size=6,aspect=1)

# %%
k1 = sns.kdeplot(peliculas.RatingsCritico,peliculas.RatingsAudiencia)

# %%
sns.set_style('darkgrid')
k1 = sns.kdeplot(peliculas.RatingsCritico,peliculas.RatingsAudiencia,shade=True,shade_lowest=False, cmap='Reds')

#tip
k2 = sns.kdeplot(peliculas.RatingsCritico,peliculas.RatingsAudiencia,cmap='Reds')

# %%
#subplots()

# %%
sns.set_style('dark')
k1 = sns.kdeplot(peliculas.PresupuestoMillonario, peliculas.RatingsAudiencia)

# %%
k2 = sns.kdeplot(peliculas.PresupuestoMillonario, peliculas.RatingsCritico)

# %%
f, axes = plt.subplots(1,2 ,figsize=(12,6))
k1 = sns.kdeplot(peliculas.PresupuestoMillonario, peliculas.RatingsAudiencia,ax=axes[0])
k2 = sns.kdeplot(peliculas.PresupuestoMillonario, peliculas.RatingsCritico)

# %%
f, axes = plt.subplots(1,2 ,figsize=(12,6), sharex=True, sharey=True)
k1 = sns.kdeplot(peliculas.PresupuestoMillonario, peliculas.RatingsAudiencia,ax=axes[0])
k2 = sns.kdeplot(peliculas.PresupuestoMillonario, peliculas.RatingsCritico)
k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
# Out:
# [(-20, 160)]

# %%
f, axes = plt.subplots(2,2 ,figsize=(12,6))
k1 = sns.kdeplot(peliculas.PresupuestoMillonario, peliculas.RatingsAudiencia,ax=axes[0,1])
k2 = sns.kdeplot(peliculas.PresupuestoMillonario, peliculas.RatingsCritico,ax=axes[1,0])

# %%
#Violinplot vs boxplot
#Diagrama de violin

# %%
z = sns.violinplot(data=peliculas,x='genero',y='RatingsCritico')

# %%
z = sns.boxplot(data=peliculas,x='genero',y='RatingsCritico')

# %%
#Diferencia de violinplot vs boxplot
f, axes = plt.subplots(1,2 ,figsize=(12,6),sharex=True, sharey=True)
z1 = sns.violinplot(data=peliculas,x='genero',y='RatingsCritico',ax=axes[0])
z2 = sns.boxplot(data=peliculas,x='genero',y='RatingsCritico')

# %%
#comparando el genero drama por año 
f, axes = plt.subplots(1,2 ,figsize=(12,6),sharex=True, sharey=True)
w1 = sns.violinplot(data=peliculas[peliculas.genero=='Drama'],x="Año",y="RatingsCritico",ax=axes[0])
w2 = sns.boxplot(data=peliculas[peliculas.genero=='Drama'],x="Año",y="RatingsCritico")

# %%
#creando un facet grid
g = sns.FacetGrid(peliculas,row='genero',hue='genero', col='Año')
g = g.map(plt.scatter, 'RatingsCritico', 'RatingsAudiencia')

# %%
#se puede rellenar con cualquier tipo de grafico
g = sns.FacetGrid(peliculas,row='genero',hue='genero', col='Año')
g = g.map(plt.hist, 'PresupuestoMillonario')

# %%
g = sns.FacetGrid(peliculas,row='genero',hue='genero', col='Año')
kws = dict(s=50, linewidth=0.5, edgecolor='black')
g = g.map(plt.scatter, 'RatingsCritico', 'RatingsAudiencia', **kws)

# %%
#Coordenadas y diagonales
#controlandos ejers

g = sns.FacetGrid(peliculas,row='genero',hue='genero', col='Año')
kws = dict(s=50, linewidth=0.5, edgecolor='black')
g = g.map(plt.scatter, 'RatingsCritico', 'RatingsAudiencia', **kws)
g.set(xlim=(0,100), ylim=(0,100))

for ax in g.axes.flat:
    ax.plot((0,100),(0,100), c='gray', ls='--')
    
g.add_legend()

# %%
#construyendo dashnoards

# %%
sns.set_style('darkgrid')
f, axes = plt.subplots(3,3 , figsize=(15,15))

#Grafico [0]
w1 = sns.violinplot(data=peliculas[peliculas.genero=='Drama'],x="Año",y="RatingsCritico",ax=axes[0,0])
axes[0,1].hist(peliculas[peliculas.genero == 'Drama'].PresupuestoMillonario)
w2 = sns.boxplot(data=peliculas[peliculas.genero=='Drama'],x="Año",y="RatingsCritico",ax=axes[0,2])

#Grafico [1]
k1 = sns.kdeplot(peliculas.RatingsCritico,peliculas.RatingsAudiencia,shade=True,shade_lowest=False, cmap='Reds',ax=axes[1,0])
k1 = sns.kdeplot(peliculas.PresupuestoMillonario, peliculas.RatingsAudiencia,ax=axes[1,1])
y1 = sns.kdeplot(peliculas.RatingsCritico,peliculas.RatingsAudiencia,ax=axes[1,2])

#Grafico [2]

k2 = sns.kdeplot(peliculas.PresupuestoMillonario, peliculas.RatingsCritico, shade=True , shadelowest=True,cmap='inferno', ax=axes[2,0])
k2b = sns.kdeplot(peliculas.PresupuestoMillonario, peliculas.RatingsCritico, ax=axes[2,0])
z = sns.violinplot(data=peliculas,x='genero',y='RatingsCritico',ax=axes[2,1])
m2 = sns.distplot(peliculas.RatingsCritico, bins=15,ax=axes[2,2])
plt.show()

# %%
lista1 = list()
mis_etiquetas = list()

for gen in peliculas.genero.cat.categories:
    lista1.append(peliculas[peliculas.genero == gen].PresupuestoMillonario)
    mis_etiquetas.append(gen)
fig, ax = plt.subplots(1,1)
fig.set_size_inches(11.7,8.27) # tamaño en pulgada de una hoja A4    

h = plt.hist(lista1,bins=30,stacked=True,rwidth=1,edgecolor='none', label=mis_etiquetas)
plt.title('Distribucion de Presupuestos para las peliculas', fontsize=35, color='DarkBlue',fontname="Console")
plt.ylabel('Numero de peliculas',fontsize=25, color="Green")
plt.xlabel('Presupuesto',fontsize=25,color='Green')
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(prop={'size':20})
plt.show()
